# %% [markdown]
# # Notebook 02: Redes Densas (MLP)
# En este notebook entrenaremos los modelos y evaluaremos su rendimiento.

# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)

import pandas as pd
import matplotlib.pyplot as plt

from src.data import cargar_returns
from src.models import build_dense_model
from src.training import entrenar_todos_los_modelos
from src.evaluation import construir_matriz_resultados

# %% [markdown]
# ## Cargar datos

# %%
returns = cargar_returns(verbose=True)
# Out:
# [cargar_returns] Cargados 16195 días, 23 activos

# %% [markdown]
# ## Definir y entrenar arquitecturas
# Aquí definimos las funciones lambda para crear los modelos usando la base del `src/models.py`.

# %%
builders = {
    "MLP_Small": lambda s: build_dense_model(s, hidden_units=[32]),
    "MLP_Medium": lambda s: build_dense_model(s, hidden_units=[64, 32]),
    "MLP_Large": lambda s: build_dense_model(s, hidden_units=[128, 64, 32], dropout=0.2)
}

# Entrenar (puede tardar bastante)
resultados = entrenar_todos_los_modelos(
    builders=builders,
    returns=returns,
    epochs=100,
    batch_size=32,
    patience=10,
    verbose=0
)
# Out:
# [1/48] Entrenando MLP_Small_V5_H1...
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
#     MAE test=0.01236  params=4471  épocas=23
# [2/48] Entrenando MLP_Medium_V5_H1...
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
#     MAE test=0.01233  params=10263  épocas=20
# [3/48] Entrenando MLP_Large_V5_H1...
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
#     MAE test=0.01223  params=25943  épocas=23
# [4/48] Entrenando MLP_Small_V5_H5...
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
#     MAE test=0.00564  params=4471  épocas=20
# [5/48] Entrenando MLP_Medium_V5_H5...
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
#     MAE test=0.00561  params=10263  épocas=20
# [6/48] Entrenando MLP_Large_V5_H5...
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.
#     MAE test=0.00559  params=25943  épocas=19
# [7/48] Entrenando MLP_Small_V5_H30...
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
#     MAE test=0.00240  params=4471  épocas=14
# [8/48] Entrenando MLP_Medium_V5_H30...
# Epoch 35: early stopping
# Restoring model weights from the end of the best epoch: 25.
#     MAE test=0.00233  params=10263  épocas=35
# [9/48] Entrenando MLP_Large_V5_H30...
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
#     MAE test=0.00233  params=25943  épocas=20
# [10/48] Entrenando MLP_Small_V5_H90...
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
#     MAE test=0.00130  params=4471  épocas=18
# [11/48] Entrenando MLP_Medium_V5_H90...
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 17.
#     MAE test=0.00126  params=10263  épocas=27
# [12/48] Entrenando MLP_Large_V5_H90...
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
#     MAE test=0.00127  params=25943  épocas=18
# [13/48] Entrenando MLP_Small_V10_H1...
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.
#     MAE test=0.01243  params=8151  épocas=19
# [14/48] Entrenando MLP_Medium_V10_H1...
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
#     MAE test=0.01229  params=17623  épocas=14
# [15/48] Entrenando MLP_Large_V10_H1...
# Epoch 28: early stopping
# Restoring model weights from the end of the best epoch: 18.
#     MAE test=0.01234  params=40663  épocas=28
# [16/48] Entrenando MLP_Small_V10_H5...
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
#     MAE test=0.00565  params=8151  épocas=18
# [17/48] Entrenando MLP_Medium_V10_H5...
# Epoch 29: early stopping
# Restoring model weights from the end of the best epoch: 19.
#     MAE test=0.00563  params=17623  épocas=29
# [18/48] Entrenando MLP_Large_V10_H5...
# Epoch 35: early stopping
# Restoring model weights from the end of the best epoch: 25.
#     MAE test=0.00559  params=40663  épocas=35
# [19/48] Entrenando MLP_Small_V10_H30...
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 3.
#     MAE test=0.00237  params=8151  épocas=13
# [20/48] Entrenando MLP_Medium_V10_H30...
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
#     MAE test=0.00234  params=17623  épocas=18
# [21/48] Entrenando MLP_Large_V10_H30...
# Epoch 30: early stopping
# Restoring model weights from the end of the best epoch: 20.
#     MAE test=0.00232  params=40663  épocas=30
# [22/48] Entrenando MLP_Small_V10_H90...
# Epoch 32: early stopping
# Restoring model weights from the end of the best epoch: 22.
#     MAE test=0.00131  params=8151  épocas=32
# [23/48] Entrenando MLP_Medium_V10_H90...
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
#     MAE test=0.00127  params=17623  épocas=23
# [24/48] Entrenando MLP_Large_V10_H90...
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.
#     MAE test=0.00128  params=40663  épocas=19
# [25/48] Entrenando MLP_Small_V30_H1...
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
#     MAE test=0.01236  params=22871  épocas=12
# [26/48] Entrenando MLP_Medium_V30_H1...
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 12.
#     MAE test=0.01242  params=47063  épocas=22
# [27/48] Entrenando MLP_Large_V30_H1...
# Epoch 25: early stopping
# Restoring model weights from the end of the best epoch: 15.
#     MAE test=0.01231  params=99543  épocas=25
# [28/48] Entrenando MLP_Small_V30_H5...
# Epoch 31: early stopping
# Restoring model weights from the end of the best epoch: 21.
#     MAE test=0.00568  params=22871  épocas=31
# [29/48] Entrenando MLP_Medium_V30_H5...
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
#     MAE test=0.00562  params=47063  épocas=12
# [30/48] Entrenando MLP_Large_V30_H5...
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
#     MAE test=0.00561  params=99543  épocas=12
# [31/48] Entrenando MLP_Small_V30_H30...
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
#     MAE test=0.00243  params=22871  épocas=11
# [32/48] Entrenando MLP_Medium_V30_H30...
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 3.
#     MAE test=0.00237  params=47063  épocas=13
# [33/48] Entrenando MLP_Large_V30_H30...
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 17.
#     MAE test=0.00233  params=99543  épocas=27
# [34/48] Entrenando MLP_Small_V30_H90...
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 12.
#     MAE test=0.00136  params=22871  épocas=22
# [35/48] Entrenando MLP_Medium_V30_H90...
# Epoch 39: early stopping
# Restoring model weights from the end of the best epoch: 29.
#     MAE test=0.00127  params=47063  épocas=39
# [36/48] Entrenando MLP_Large_V30_H90...
# Epoch 32: early stopping
# Restoring model weights from the end of the best epoch: 22.
#     MAE test=0.00127  params=99543  épocas=32
# [37/48] Entrenando MLP_Small_V90_H1...
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
#     MAE test=0.01246  params=67031  épocas=15
# [38/48] Entrenando MLP_Medium_V90_H1...
# Epoch 25: early stopping
# Restoring model weights from the end of the best epoch: 15.
#     MAE test=0.01239  params=135383  épocas=25
# [39/48] Entrenando MLP_Large_V90_H1...
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.
#     MAE test=0.01230  params=276183  épocas=17
# [40/48] Entrenando MLP_Small_V90_H5...
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
#     MAE test=0.00566  params=67031  épocas=23
# [41/48] Entrenando MLP_Medium_V90_H5...
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
#     MAE test=0.00561  params=135383  épocas=23
# [42/48] Entrenando MLP_Large_V90_H5...
# Epoch 37: early stopping
# Restoring model weights from the end of the best epoch: 27.
#     MAE test=0.00560  params=276183  épocas=37
# [43/48] Entrenando MLP_Small_V90_H30...
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 12.
#     MAE test=0.00236  params=67031  épocas=22
# [44/48] Entrenando MLP_Medium_V90_H30...
# Epoch 32: early stopping
# Restoring model weights from the end of the best epoch: 22.
#     MAE test=0.00233  params=135383  épocas=32
# [45/48] Entrenando MLP_Large_V90_H30...
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 14.
#     MAE test=0.00234  params=276183  épocas=24
# [46/48] Entrenando MLP_Small_V90_H90...
# Epoch 33: early stopping
# Restoring model weights from the end of the best epoch: 23.
#     MAE test=0.00133  params=67031  épocas=33
# [47/48] Entrenando MLP_Medium_V90_H90...
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
#     MAE test=0.00128  params=135383  épocas=20
# [48/48] Entrenando MLP_Large_V90_H90...
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
#     MAE test=0.00133  params=276183  épocas=15

# %% [markdown]
# ## Guardar resultados

# %%
df = pd.DataFrame(resultados).round(6)
tables_dir = project_root / "results" / "tables"
df.to_csv(tables_dir / '02_competicion_densas.csv', index=False)
df.head()
# Out:
#        modelo  V  H  MAE_train   MAE_val  MAE_test  n_params  \
# 0   MLP_Small  5  1   0.011514  0.009209  0.012360      4471
# 1  MLP_Medium  5  1   0.011600  0.009205  0.012333     10263
# 2   MLP_Large  5  1   0.011645  0.009205  0.012232     25943
# 3   MLP_Small  5  5   0.005376  0.004302  0.005642      4471
# 4  MLP_Medium  5  5   0.005383  0.004307  0.005606     10263
#
#    epocas_entrenadas
# 0                 23
# 1                 20
# 2                 23
# 3                 20
# 4                 20

# %% [markdown]
# ## Visualización (Heatmaps)

# %%
import numpy as np

modelos = list(builders.keys())
INPUT_WINDOWS  = [5, 10, 30, 90]
OUTPUT_WINDOWS = [1, 5, 30, 90]

fig, axes = plt.subplots(1, len(modelos), figsize=(7*len(modelos), 6))
if len(modelos) == 1: axes = [axes]

for idx, modelo in enumerate(modelos):
    df_modelo = df[df["modelo"] == modelo]
    resultados_modelo = df_modelo.to_dict("records")
    matriz = construir_matriz_resultados(resultados_modelo, INPUT_WINDOWS, OUTPUT_WINDOWS)

    ax = axes[idx]
    im = ax.imshow(matriz, cmap="viridis_r", origin="upper", aspect="auto")

    # Anotar valores
    for i in range(len(INPUT_WINDOWS)):
        for j in range(len(OUTPUT_WINDOWS)):
            val = matriz[i, j]
            if not np.isnan(val):
                color = "white" if val > np.nanmedian(matriz) else "black"
                ax.text(j, i, f"{val:.4f}", ha="center", va="center", color=color, fontsize=9, fontweight="bold")

    ax.set_xticks(range(len(OUTPUT_WINDOWS)))
    ax.set_yticks(range(len(INPUT_WINDOWS)))
    ax.set_xticklabels(OUTPUT_WINDOWS)
    ax.set_yticklabels(INPUT_WINDOWS)
    ax.set_xlabel("Ventana salida H (días)")
    ax.set_ylabel("Ventana entrada V (días)")
    ax.set_title(f"MAE test — {modelo}")
    plt.colorbar(im, ax=ax)

plt.tight_layout()
figures_dir = project_root / "results" / "figures"
plt.savefig(figures_dir / '02_competicion_densas_matrices.png', bbox_inches="tight", dpi=120)
plt.show()
